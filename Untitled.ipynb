# %% [markdown]
# # Emotion Detection

# %% [markdown]
# # importing libraries

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("tensorflow version:", tf.__version__)
# Out:
# tensorflow version: 2.16.1

# %% [markdown]
# # Exploring Dataset

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# # Preparing Data for Training

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/", target_size=(img_size, img_size), color_mode="grayscale", batch_size=batch_size, class_mode="categorical", shuffle=True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("train/", target_size=(img_size, img_size), color_mode="grayscale", batch_size=batch_size, class_mode="categorical", shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 28709 images belonging to 7 classes.

# %% [markdown]
# # Defining model

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters=filters, kernel_size=kernel_size, padding="same")(input_tensor)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=MaxPooling2D(pool_size = (2,2))(x)
    x=Dropout(0.25)(x)
    return x

# %%
def Dense_f(input_tensor, nodes):
    x=Dense(nodes)(input_tensor)
    x=BatchNormalization()(x)
    x=Activation('relu')(x)
    x=Dropout(0.25)(x)
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(inputs,64,(5,5))
    conv_3 = Convolution(inputs,128,(3,3))
    flatten = Flatten()(conv_3)
    dense_1 = Dense_f(flatten,256)
    output = Dense(7, activation="softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Layer (type)           ┃ Output Shape    ┃   Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ input_layer_13         │ (None, 48, 48,  │         0 │
# │ (InputLayer)           │ 1)              │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ conv2d_15 (Conv2D)     │ (None, 48, 48,  │     1,280 │
# │                        │ 128)            │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ batch_normalization_19 │ (None, 48, 48,  │       512 │
# │ (BatchNormalization)   │ 128)            │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ activation_19          │ (None, 48, 48,  │         0 │
# │ (Activation)           │ 128)            │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ max_pooling2d_14       │ (None, 24, 24,  │         0 │
# │ (MaxPooling2D)         │ 128)            │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ dropout_18 (Dropout)   │ (None, 24, 24,  │         0 │
# │                        │ 128)            │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ flatten_4 (Flatten)    │ (None, 73728)   │         0 │
# ├────────────────────────┼─────────────────┼───────────┤
# │ dense_8 (Dense)        │ (None, 256)     │ 18,874,6… │
# ├────────────────────────┼─────────────────┼───────────┤
# │ batch_normalization_20 │ (None, 256)     │     1,024 │
# │ (BatchNormalization)   │                 │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ activation_20          │ (None, 256)     │         0 │
# │ (Activation)           │                 │           │
# ├────────────────────────┼─────────────────┼───────────┤
# │ dropout_19 (Dropout)   │ (None, 256)     │         0 │
# ├────────────────────────┼─────────────────┼───────────┤
# │ dense_9 (Dense)        │ (None, 7)       │     1,799 │
# └────────────────────────┴─────────────────┴───────────┘
#  Total params: 18,879,239 (72.02 MB)
#  Trainable params: 18,878,471 (72.02 MB)
#  Non-trainable params: 768 (3.00 KB)

# %% [markdown]
# # Intializing the Model

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weight.weights.h5", monitor='val_accuracy', save_weights_only=True, mode='max', verbose=1)
callbacks = [checkpoint]

# %% [markdown]
# # Traning the Model

# %% [markdown]
# ## next cell take time to complete

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = steps_per_epoch,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = validation_steps,
    callbacks=callbacks)
# Out:
# Epoch 1/15
# C:\Users\kavya\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3396 - loss: 1.7837
# Epoch 1: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 724s 2s/step - accuracy: 0.3397 - loss: 1.7834 - val_accuracy: 0.3555 - val_loss: 1.7416
# Epoch 2/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:01 942ms/step - accuracy: 0.4531 - loss: 1.5366
# Epoch 2: saving model to model_weight.weights.h5
# E:\Users\20486021\anaconda3\envs\emotion_detection_course\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(value)
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4531 - loss: 1.5366 - val_accuracy: 0.3784 - val_loss: 1.7098
# Epoch 3/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 952ms/step - accuracy: 0.4947 - loss: 1.3400
# Epoch 3: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 600s 1s/step - accuracy: 0.4947 - loss: 1.3400 - val_accuracy: 0.3924 - val_loss: 1.4718
# Epoch 4/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:28 736ms/step - accuracy: 0.4375 - loss: 1.4777
# Epoch 4: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4375 - loss: 1.4777 - val_accuracy: 0.5676 - val_loss: 1.1953
# Epoch 5/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5522 - loss: 1.1878
# Epoch 5: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 663s 1s/step - accuracy: 0.5522 - loss: 1.1879 - val_accuracy: 0.5114 - val_loss: 1.2689
# Epoch 6/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 5:49 782ms/step - accuracy: 0.6875 - loss: 0.9705
# Epoch 6: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6875 - loss: 0.9705 - val_accuracy: 0.4595 - val_loss: 1.4082
# Epoch 7/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6198 - loss: 1.0427
# Epoch 7: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 691s 2s/step - accuracy: 0.6198 - loss: 1.0427 - val_accuracy: 0.6325 - val_loss: 1.0453
# Epoch 8/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 7:04 949ms/step - accuracy: 0.5469 - loss: 1.2040
# Epoch 8: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5469 - loss: 1.2040 - val_accuracy: 0.6486 - val_loss: 0.9903
# Epoch 9/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6760 - loss: 0.9032
# Epoch 9: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 646s 1s/step - accuracy: 0.6760 - loss: 0.9032 - val_accuracy: 0.4837 - val_loss: 1.5678
# Epoch 10/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 8:04 1s/step - accuracy: 0.5625 - loss: 1.0981
# Epoch 10: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5625 - loss: 1.0981 - val_accuracy: 0.4865 - val_loss: 1.5552
# Epoch 11/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 990ms/step - accuracy: 0.7202 - loss: 0.7931
# Epoch 11: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 602s 1s/step - accuracy: 0.7202 - loss: 0.7932 - val_accuracy: 0.7520 - val_loss: 0.7486
# Epoch 12/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 6:08 824ms/step - accuracy: 0.5781 - loss: 1.1195
# Epoch 12: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5781 - loss: 1.1195 - val_accuracy: 0.7568 - val_loss: 0.6745
# Epoch 13/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7594 - loss: 0.6769
# Epoch 13: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 728s 2s/step - accuracy: 0.7594 - loss: 0.6770 - val_accuracy: 0.7988 - val_loss: 0.6328
# Epoch 14/15
#   1/448 ━━━━━━━━━━━━━━━━━━━━ 9:30 1s/step - accuracy: 0.6719 - loss: 0.8163
# Epoch 14: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6719 - loss: 0.8163 - val_accuracy: 0.6486 - val_loss: 0.7570
# Epoch 15/15
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.8088 - loss: 0.5573
# Epoch 15: saving model to model_weight.weights.h5
# 448/448 ━━━━━━━━━━━━━━━━━━━━ 593s 1s/step - accuracy: 0.8088 - loss: 0.5574 - val_accuracy: 0.8088 - val_loss: 0.5609

# %% [markdown]
# ## Model Evalution

# %%
model.evaluate(validation_generator)
# Out:
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 238s 530ms/step - accuracy: 0.8115 - loss: 0.5523
# [0.5608628988265991, 0.8087359070777893]

# %% [markdown]
# ## Plotting Loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.legend(['Train', 'validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0, hspace=0.25, wspace=0.35)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.legend(['Train', 'validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0, hspace=0.25, wspace=0.35)

# %% [markdown]
# ### Saving Model

# %%
model_json=model.to_json()
with open("model.a.json","w") as json_file:
    json_file.write(model_json)
